# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
za_data = pd.read_csv("Classification/cleanedartistsong.csv")

# %%
za_data.columns
# Out:
# Index(['main_artist', 'track_name', 'Max Streams per Song',
#        'Min Streams per Song', 'Total Streams per Song',
#        'Mean Streams per Song', 'Min Position per Song',
#        'MaxMin Difference Position', 'MaxMin Difference Streams',
#        'MaxMin Ratio Position', 'MaxMin Ratio Streams',
#        'Max Song Count per artist', 'Max Weeks on Chart per song',
#        'first_week_rank', 'first_week_streams', 'Max Artist Appearance',
#        'encoded_source'],
#       dtype='object')

# %%
za_data.head(5)
# Out:
#    main_artist                                         track_name  \
# 0         $NOT                                               Doja
# 1  $uicideboy$  ...And to Those I Love, Thanks for Sticking Ar...
# 2    031CHOPPA                                          Usenemali
# 3     2 Chainz              Bigger Than You (feat. Drake & Quavo)
# 4     2 Chainz               Rule The World (feat. Ariana Grande)
#
#    Max Streams per Song  Min Streams per Song  Total Streams per Song  \
# 0                 23789                 23789                   23789
# 1                 23341                 23341                   23341
# 2                 35968                 35968                   35968
# 3                  5994                  3964                   32044
# 4                  8536                  8536                    8536
#
#    Mean Streams per Song  Min Position per Song  MaxMin Difference Position  \
# ...

# %%
za_data.columns
# Out:
# Index(['main_artist', 'track_name', 'Max Streams per Song',
#        'Min Streams per Song', 'Total Streams per Song',
#        'Mean Streams per Song', 'Min Position per Song',
#        'MaxMin Difference Position', 'MaxMin Difference Streams',
#        'MaxMin Ratio Position', 'MaxMin Ratio Streams',
#        'Max Song Count per artist', 'Max Weeks on Chart per song',
#        'first_week_rank', 'first_week_streams', 'Max Artist Appearance',
#        'encoded_source'],
#       dtype='object')

# %%
# Load the dataset
# Split data into features and target variable
X = za_data[['main_artist', 'track_name', 'Max Streams per Song','Min Streams per Song', 'Total Streams per Song','Mean Streams per Song', 'Min Position per Song','MaxMin Difference Position', 'MaxMin Difference Streams','MaxMin Ratio Position', 'MaxMin Ratio Streams','Max Song Count per artist','first_week_rank', 'first_week_streams', 'Max Artist Appearance','encoded_source']]  # Include relevant features
y = za_data['Max Weeks on Chart per song']

# %%
# Encode categorical variables (e.g., one-hot encoding)
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Initialize and train a decision tree regressor
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 49.34924078091106
# R-squared: 0.903015477022333

# %%
list(X_test.columns)
# Out:
# ['Max Streams per Song',
#  'Min Streams per Song',
#  'Total Streams per Song',
#  'Mean Streams per Song',
#  'Min Position per Song',
#  'MaxMin Difference Position',
#  'MaxMin Difference Streams',
#  'MaxMin Ratio Position',
#  'MaxMin Ratio Streams',
#  'Max Song Count per artist',
#  'first_week_rank',
#  'first_week_streams',
#  'Max Artist Appearance',
#  'encoded_source',
#  'main_artist_$NOT',
#  'main_artist_$uicideboy$',
#  'main_artist_031CHOPPA',
#  'main_artist_2 Chainz',
#  'main_artist_21 Savage',
#  'main_artist_24kGoldn',
#  'main_artist_25K',
#  'main_artist_2Point1',
#  'main_artist_347aidan',
#  'main_artist_5 Seconds of Summer',
#  'main_artist_6LACK',
#  'main_artist_6ix9ine',
#  'main_artist_9umba',
#  'main_artist_A Boogie Wit da Hoodie',
#  'main_artist_A$AP Ferg',
#  'main_artist_A$AP Rocky',
#  'main_artist_A-Reece',
#  'main_artist_AC/DC',
#  'main_artist_ACRAZE',
#  'main_artist_AJR',
#  'main_artist_AKA',
#  'main_artist_ANATII',
# ...

# %%
y_pred
# Out:
# array([  2.,   2.,   2.,  51.,   3.,  23.,   1.,   2.,   1.,  25.,   6.,
#          1.,   1.,  18.,   2.,   3.,   7.,  29.,  59.,   2.,  15.,  65.,
#         24.,   4.,   1.,   1.,   1.,  24.,   3.,   1.,  38.,   2.,  14.,
#          1.,   1.,   5.,   5.,  14.,  13.,   1.,   7.,  18.,   2.,   1.,
#          1.,   3.,  42.,   4.,   1.,  11.,   1.,   1.,   1.,  98.,   2.,
#          1.,   1.,   6.,   1.,   4.,   9.,   2.,   1.,   1.,   4.,  28.,
#          4.,   2.,   1.,   3.,   2.,  73.,   2.,   9.,   1.,   5.,   3.,
#         15.,   1.,   2.,  22.,  38.,   1.,   1.,   1.,  15.,  27.,   8.,
#         22.,   1.,   2.,   3.,   1.,   1.,   4.,   1.,   8., 122.,  59.,
#         13.,   3.,   2.,   1.,  25.,   2.,   2.,   2.,   1.,   6.,   3.,
#         34.,   1.,  45.,   1.,  36.,   5.,   5.,   3.,  19.,   1.,   6.,
#          4.,  12.,   1.,   6.,   1.,   2.,   1.,  29.,   1.,   1.,   1.,
#          1.,  20.,   2.,   7.,   1.,  29.,  21.,   1.,  38.,   1.,   3.,
# ...
