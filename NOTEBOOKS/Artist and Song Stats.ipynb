# %%
import pandas as pd
import json
import string

# %%
all_files_za = pd.read_csv("Classification/all_files_ZAv1.csv")

# %%
# end_dt_df = all_files_za[all_files_za["End Date"] == "2022-02-10"]
# main_artist_df = all_files_za[all_files_za["main_artist"] == "9umba"]

# %%
main_artist_val = "9umba"
song_name_val = "uMlando"

artist_and_song = all_files_za[(all_files_za["main_artist"] == main_artist_val) & (all_files_za["track_name"]  == song_name_val)]

# %%
artist_and_song
# Out:
#      trackAppearanceCount  artistAppearanceCount  rank  \
# 682                     0                      0     2
# 683                     1                      1     2
# 684                     2                      2     2
# 685                     3                      3     2
# 686                     4                      4     3
# 687                     5                      5     3
# 688                     6                      6     4
# 689                     7                      7     3
# 690                     8                      8     3
# 691                     9                      9     2
# 692                    10                     10     4
# 693                    11                     11     5
# 694                    12                     12     6
# 695                    13                     13     6
# 696                    14                     14     6
# 697                    15                     15     7
# ...
